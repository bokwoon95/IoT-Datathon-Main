# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('71var.csv',index_col=0)
#df.dropna(inplace=True)
df.head()
# Out:
#                 C1ch1Watt  C1ch2Watt   C1ch3Watt  C1PositiveWattHour  \
# 30/5/17 22:00  352.275862        0.0  349.655172          705.172414
# 30/5/17 23:00  352.344828        0.0  349.051724          693.103448
# 31/5/17 00:00  347.293103        0.0  343.724138          693.103448
# 31/5/17 01:00  348.103448        0.0  343.931035          698.275862
# 31/5/17 02:00  350.293103        0.0  347.310345          693.738657
#
#                  C1temp1    C1temp2    C1temp3    C1temp4   C1t2-t1   C1t3-t4  \
# 30/5/17 22:00  23.672817  26.667634  28.195216  28.155696  2.994817  0.039520
# 30/5/17 23:00  23.705038  26.669592  28.079504  28.050665  2.964554  0.028839
# 31/5/17 00:00  23.724798  26.681697  27.986578  27.955959  2.956899  0.030620
# 31/5/17 01:00  23.788529  26.739197  27.926051  27.869442  2.950668  0.056610
# 31/5/17 02:00  23.808111  26.763764  27.852174  27.771887  2.955653  0.080287
#
#                  ...     C4c.flowSpeed  C4Coolingcap  C4 O_F     powersum  \
# ...

# %%
df=df.reset_index().reset_index()

# %%
df=df.set_index('index')

# %%
df.rename(columns={'level_0':'time'},inplace=True)

# %%
df.index.name='ts'

# %%
df
# Out:
#                 time   C1ch1Watt  C1ch2Watt   C1ch3Watt  C1PositiveWattHour  \
# ts
# 30/5/17 22:00      0  352.275862        0.0  349.655172          705.172414
# 30/5/17 23:00      1  352.344828        0.0  349.051724          693.103448
# 31/5/17 00:00      2  347.293103        0.0  343.724138          693.103448
# 31/5/17 01:00      3  348.103448        0.0  343.931035          698.275862
# 31/5/17 02:00      4  350.293103        0.0  347.310345          693.738657
# 31/5/17 03:00      5  346.666667        0.0  344.017544          683.847550
# 31/5/17 04:00      6  345.844828        0.0  343.258621          687.931035
# 31/5/17 05:00      7  344.258621        0.0  343.568965          687.931035
# 31/5/17 06:00      8  341.827586        0.0  340.689655          686.206897
# 31/5/17 07:00      9  341.103448        0.0  347.741379          693.103448
# 31/5/17 08:00     10  336.913793        0.0  357.275862          697.019287
# ...

# %%
df['fan_on'] = np.where(df['fan1']>1, 1, 0)+np.where(df['fan2']>1, 1, 0)+np.where(df['fan3']>1, 1, 0)+np.where(df['fan4']>1, 1, 0)

# %%
df
# Out:
#                 time   C1ch1Watt  C1ch2Watt   C1ch3Watt  C1PositiveWattHour  \
# ts
# 30/5/17 22:00      0  352.275862        0.0  349.655172          705.172414
# 30/5/17 23:00      1  352.344828        0.0  349.051724          693.103448
# 31/5/17 00:00      2  347.293103        0.0  343.724138          693.103448
# 31/5/17 01:00      3  348.103448        0.0  343.931035          698.275862
# 31/5/17 02:00      4  350.293103        0.0  347.310345          693.738657
# 31/5/17 03:00      5  346.666667        0.0  344.017544          683.847550
# 31/5/17 04:00      6  345.844828        0.0  343.258621          687.931035
# 31/5/17 05:00      7  344.258621        0.0  343.568965          687.931035
# 31/5/17 06:00      8  341.827586        0.0  340.689655          686.206897
# 31/5/17 07:00      9  341.103448        0.0  347.741379          693.103448
# 31/5/17 08:00     10  336.913793        0.0  357.275862          697.019287
# ...

# %%
import statsmodels as sm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-a4673a3f56bb> in <module>()
# ----> 1 import statsmodels as sm
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
df.columns

# %%
X=df.drop(['powersum'],axis=1)
y=df['powersum']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
